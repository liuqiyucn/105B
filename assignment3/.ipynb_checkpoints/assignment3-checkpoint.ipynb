# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import scienceplots
plt.style.use(['science', 'notebook', 'grid'])
from numpy.fft import fft, fftfreq, fftshift, ifft
pi = np.pi

# %% [markdown]
# # 1a

# %%
N = np.arange(100)
t = 0.1*pi*N
def generate_data(time, omega):
    return np.cos(omega*time)
d = generate_data(t, omega=2)
sp = np.fft.fft(d)
plt.plot(N, np.abs(sp))
plt.show()

# %% [markdown]
# # 1b

# %%
freq = np.fft.fftfreq(N.shape[-1])
plt.plot(freq, np.abs(sp))
plt.show()

# %% [markdown]
# # 1c

# %%
plt.plot(np.fft.fftshift(freq), np.abs(sp))
plt.show()

# %% [markdown]
# # 1d

# %%
d2 = generate_data(t, omega=5)
d3 = generate_data(t, omega=19)

sp2 = np.fft.fft(d2)
sp3 = np.fft.fft(d3)

plt.plot(fftshift(freq), fftshift(np.abs(sp)), label = "w = 2")
plt.plot(fftshift(freq), fftshift(np.abs(sp2)), label = "w = 5")
plt.plot(fftshift(freq), fftshift(np.abs(sp3)), label = "w = 19")
plt.legend()
plt.show()

# %% [markdown]
# # 1e

# %%
fig, ax = plt.subplots()
ax.plot(t, d, label = "w = 2")
ax.plot(t, d2, label = "w = 5")
ax.plot(t, d3, label = "w = 19")
plt.legend()
plt.show()

# %% [markdown]
# # 2a

# %%
N = np.arange(1000)
t = 0.01* N
d = np.cos(6*pi*t) + np.random.normal(0, 3, 1000)
signal = np.cos(6*pi*t)
plt.plot(t, signal, label = "signal")
plt.plot(t, d, label = "data")
plt.legend()
# maybe subplot?

# %% [markdown]
# # 2b

# %%
sp = fft(d)
freq = fftfreq(N.shape[-1])
plt.plot(fftshift(freq), fftshift(np.abs(sp)))
plt.show()

# %% [markdown]
# # 2c

# %%
N = np.arange(100)
t = 0.01* N
d = np.cos(6*pi*t) + np.random.normal(0, 3, 100)

N = np.arange(3000)
t = 0.01* N
d = np.cos(6*pi*t) + np.random.normal(0, 3, 3000)

N = np.arange(6000)
t = 0.01* N
d = np.cos(6*pi*t) + np.random.normal(0, 3, 6000)

# %% [markdown]
# # 3a

# %%
t = np.arange(100)* 0.1*pi
dt = t[-1]/t.size
g = np.exp(-t/20)*np.cos(5*t)
h = np.exp(-(t**2/(2*0.1)))/np.sqrt(2*pi*0.1) + np.exp(-((t-100*0.1*pi)**2/(2*0.1)))/np.sqrt(2*pi*0.1)

# %%
plt.plot(t, g, label = "g(t)")
plt.plot(t, h, label = "h(t)")
plt.legend()

# %%
sp_g = fft(g)
sp_h = fft(h)
sp_f = sp_g*sp_h

f = ifft(sp_f)*dt
plt.plot(t, np.real(f))

# %%
sp_f = fft(f)
sp_g = sp_f/sp_h
g = ifft(sp_g)

plt.plot(t, np.real(g)/dt)

# %%
f_noise = f + np.random.normal(100)
