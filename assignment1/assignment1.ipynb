# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1a

# %%
a = np.array([1,1,1])
b = np.array([2,2,2])
c = np.array([3,3,3])
a+b-c
# Out:
# array([0, 0, 0])

# %% [markdown]
# 1b

# %%
def add_array(a,b):
    if a.size != b.size:
        return "Dimension Error"
    else:
        return a+b

array_1 = np.array([3,5,7])
array_2 = np.array([1,1,1])
array_3 = np.array([2,2,2,2])

print(add_array(array_1,array_2))
print(add_array(array_1,array_3))
# Out:
# [4 6 8]
# Dimension Error

# %% [markdown]
# 1c

# %%
fig, ax = plt.subplots(figsize=(10,8), nrows=1, ncols = 2)
time = np.linspace(0,10,101)
cos_y = np.cos(time)
sin_y = np.sin(time)
ax[0,0].plot(time, sin_y)
ax[1,1].plot(time, cos_y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 5
#       3 cos_y = np.cos(time)
#       4 sin_y = np.sin(time)
# ----> 5 ax[0,0].plot(time, sin_y)
#       6 ax[0,1].plot(time, cos_y)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
